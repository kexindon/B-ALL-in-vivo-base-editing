# %% [markdown]
# # count matrix
# This script generates a table that has columns of samples and rows of guide counts.
#
# VERY IMPORTANT: to only keep ABE or CBE guides in ABE/ CBE subpool files!
#
# Kexin Dong
#
# Dec 2, 2025

# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
import re
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42   
mpl.rcParams['ps.fonttype'] = 42 
mpl.rcParams['text.usetex'] = False

# %%
config = pd.read_csv('CONFIG_BALL_VALIDATION_SCREEN.txt', sep=' ')
list(config['folder_name'])
# Out:
# ['D25-13245-1-7331E_guide_split_BARCODES',
#  'D25-13245-2-7331E_guide_split_BARCODES',
#  'D25-13246-1-7331E_guide_split_BARCODES',
#  'D25-13246-2-7331E_guide_split_BARCODES',
#  'D25-13247-1-7331E_guide_split_BARCODES',
#  'D25-13247-2-7331E_guide_split_BARCODES',
#  'D25-13248-1-7331E_guide_split_BARCODES',
#  'D25-13248-2-7331E_guide_split_BARCODES',
#  'D25-13249-1-7331E_guide_split_BARCODES',
#  'D25-13249-2-7331E_guide_split_BARCODES',
#  'D25-13250-1-7331E_guide_split_BARCODES',
#  'D25-13250-2-7331E_guide_split_BARCODES',
#  'D25-13251-1-7331E_guide_split_BARCODES',
#  'D25-13251-2-7331E_guide_split_BARCODES',
#  'D25-13252-1-7331E_guide_split_BARCODES',
#  'D25-13252-2-7331E_guide_split_BARCODES',
#  'D25-13253-1-7331E_guide_split_BARCODES',
#  'D25-13253-2-7331E_guide_split_BARCODES',
#  'D25-13254-1-7331E_guide_split_BARCODES',
#  'D25-13254-2-7331E_guide_split_BARCODES',
#  'D25-13255-1-7331E_guide_split_BARCODES',
#  'D25-13255-2-7331E_guide_split_BARCODES',
#  'D25-13256-1-7331E_guide_split_BARCODES',
#  'D25-13256-2-7331E_guide_split_BARCODES',
#  'D25-13257-1-7331E_guide_split_BARCODES',
#  'D25-13257-2-7331E_guide_split_BARCODES',
#  'D25-13258-1-7331E_guide_split_BARCODES',
#  'D25-13258-2-7331E_guide_split_BARCODES',
#  'D25-13259-1-7331E_guide_split_BARCODES',
#  'D25-13259-2-7331E_guide_split_BARCODES',
#  'D25-13260-1-7331E_guide_split_BARCODES',
#  'D25-13260-2-7331E_guide_split_BARCODES',
#  'D25-13261-1-7331E_guide_split_BARCODES',
#  'D25-13261-2-7331E_guide_split_BARCODES',
#  'D25-13262-1-7331E_guide_split_BARCODES',
#  'D25-13262-2-7331E_guide_split_BARCODES',
#  'D25-13263-1-7331E_guide_split_BARCODES',
#  'D25-13263-2-7331E_guide_split_BARCODES',
#  'D25-13264-1-7331E_guide_split_BARCODES',
#  'D25-13264-2-7331E_guide_split_BARCODES',
#  'D25-13265-1-7331E_guide_split_BARCODES',
#  'D25-13265-2-7331E_guide_split_BARCODES',
#  'D25-13266-1-7331E_guide_split_BARCODES',
#  'D25-13266-2-7331E_guide_split_BARCODES',
#  'D25-13267-1-7331E_guide_split_BARCODES',
#  'D25-13267-2-7331E_guide_split_BARCODES',
#  'D25-13268-1-7331E_guide_split_BARCODES',
#  'D25-13268-2-7331E_guide_split_BARCODES',
#  'D25-13269-1-7331E_guide_split_BARCODES',
#  'D25-13269-2-7331E_guide_split_BARCODES',
#  'D25-13270-1-7331E_guide_split_BARCODES',
#  'D25-13270-2-7331E_guide_split_BARCODES',
#  'D25-13271-1-7331E_guide_split_BARCODES',
#  'D25-13271-2-7331E_guide_split_BARCODES',
#  'D25-13272-1-7331E_guide_split_BARCODES',
#  'D25-13272-2-7331E_guide_split_BARCODES',
#  'D25-13273-1-7331E_guide_split_BARCODES',
#  'D25-13273-2-7331E_guide_split_BARCODES',
#  'D25-13274-1-7331E_guide_split_BARCODES',
#  'D25-13274-2-7331E_guide_split_BARCODES',
#  'D25-13275-1-7331E_guide_split_BARCODES',
#  'D25-13275-2-7331E_guide_split_BARCODES',
#  'D25-13276-1-7331E_guide_split_BARCODES',
#  'D25-13276-2-7331E_guide_split_BARCODES',
#  'D25-13277-1-7331E_guide_split_BARCODES',
#  'D25-13277-2-7331E_guide_split_BARCODES',
#  'D25-13278-1-7331E_guide_split_BARCODES',
#  'D25-13278-2-7331E_guide_split_BARCODES',
#  'D25-13279-1-7331E_guide_split_BARCODES',
#  'D25-13279-2-7331E_guide_split_BARCODES',
#  'D25-13280-1-7331E_guide_split_BARCODES',
#  'D25-13280-2-7331E_guide_split_BARCODES',
#  'D25-13281-1-7331E_guide_split_BARCODES',
#  'D25-13281-2-7331E_guide_split_BARCODES',
#  'D25-13282-1-7331E_guide_split_BARCODES',
#  'D25-13282-2-7331E_guide_split_BARCODES',
#  'D25-13283-1-7331E_guide_split_BARCODES',
#  'D25-13283-2-7331E_guide_split_BARCODES',
#  'D25-13284-1-7331E_guide_split_BARCODES',
#  'D25-13284-2-7331E_guide_split_BARCODES',
#  'D25-13285-1-7331E_guide_split_BARCODES',
#  'D25-13285-2-7331E_guide_split_BARCODES',
#  'D25-13286-1-7331E_guide_split_BARCODES',
#  'D25-13286-2-7331E_guide_split_BARCODES',
#  'D25-13287-1-7331E_guide_split_BARCODES',
#  'D25-13287-2-7331E_guide_split_BARCODES',
#  'D25-13288-1-7331E_guide_split_BARCODES',
#  'D25-13288-2-7331E_guide_split_BARCODES',
#  'D25-13289-1-7331E_guide_split_BARCODES',
#  'D25-13289-2-7331E_guide_split_BARCODES',
#  'D25-13290-1-7331E_guide_split_BARCODES',
#  'D25-13290-2-7331E_guide_split_BARCODES',
#  'D25-13291-1-7331E_guide_split_BARCODES',
#  'D25-13291-2-7331E_guide_split_BARCODES',
#  'D25-13292-1-7331E_guide_split_BARCODES',
#  'D25-13292-2-7331E_guide_split_BARCODES',
#  'D25-13293-1-7331E_guide_split_BARCODES',
#  'D25-13293-2-7331E_guide_split_BARCODES',
#  'D25-13294-1-7331E_guide_split_BARCODES',
#  'D25-13294-2-7331E_guide_split_BARCODES',
#  'D25-13295-1-7331E_guide_split_BARCODES',
#  'D25-13295-2-7331E_guide_split_BARCODES',
#  'D25-13296-1-7331E_guide_split_BARCODES',
#  'D25-13296-2-7331E_guide_split_BARCODES',
#  'D25-13297-1-7331E_guide_split_BARCODES',
#  'D25-13297-2-7331E_guide_split_BARCODES',
#  'D25-13298-1-7331E_guide_split_BARCODES',
#  'D25-13298-2-7331E_guide_split_BARCODES',
#  'D25-13299-1-7331E_guide_split_BARCODES',
#  'D25-13299-2-7331E_guide_split_BARCODES',
#  'D25-13300-1-7331E_guide_split_BARCODES',
#  'D25-13300-2-7331E_guide_split_BARCODES',
#  'D25-13301-1-7331E_guide_split_BARCODES',
#  'D25-13301-2-7331E_guide_split_BARCODES',
#  'D25-13302-1-7331E_guide_split_BARCODES',
#  'D25-13302-2-7331E_guide_split_BARCODES',
#  'D25-13303-1-7331E_guide_split_BARCODES',
#  'D25-13303-2-7331E_guide_split_BARCODES',
#  'D25-13304-1-7331E_guide_split_BARCODES',
#  'D25-13304-2-7331E_guide_split_BARCODES',
#  'D25-13305-1-7331E_guide_split_BARCODES',
#  'D25-13305-2-7331E_guide_split_BARCODES',
#  'D25-13306-1-7331E_guide_split_BARCODES',
#  'D25-13306-2-7331E_guide_split_BARCODES',
#  'D25-13307-1-7331E_guide_split_BARCODES',
#  'D25-13307-2-7331E_guide_split_BARCODES',
#  'D25-13308-1-7331E_guide_split_BARCODES',
#  'D25-13308-2-7331E_guide_split_BARCODES',
#  'D25-13309-1-7331E_guide_split_BARCODES',
#  'D25-13309-2-7331E_guide_split_BARCODES',
#  'D25-13310-1-7331E_guide_split_BARCODES',
#  'D25-13310-2-7331E_guide_split_BARCODES',
#  'D25-13311-1-7331E_guide_split_BARCODES',
#  'D25-13311-2-7331E_guide_split_BARCODES',
#  'D25-13312-1-7331E_guide_split_BARCODES',
#  'D25-13312-2-7331E_guide_split_BARCODES',
#  'D25-13313-1-7331E_guide_split_BARCODES',
#  'D25-13313-2-7331E_guide_split_BARCODES',
#  'D25-13314-1-7331E_guide_split_BARCODES',
#  'D25-13314-2-7331E_guide_split_BARCODES',
#  'D25-13315-1-7331E_guide_split_BARCODES',
#  'D25-13315-2-7331E_guide_split_BARCODES',
#  'D25-13316-1-7331E_guide_split_BARCODES',
#  'D25-13316-2-7331E_guide_split_BARCODES',
#  'D25-13317-1-7331E_guide_split_BARCODES',
#  'D25-13317-2-7331E_guide_split_BARCODES',
#  'D25-13321-1-7331E_guide_split_BARCODES',
#  'D25-13321-2-7331E_guide_split_BARCODES',
#  'D25-13322-1-7331E_guide_split_BARCODES',
#  'D25-13322-2-7331E_guide_split_BARCODES',
#  'D25-13324-1-7331E_guide_split_BARCODES',
#  'D25-13324-2-7331E_guide_split_BARCODES',
#  'D25-13325-1-7331E_guide_split_BARCODES',
#  'D25-13325-2-7331E_guide_split_BARCODES',
#  'D25-13326-1-7331E_guide_split_BARCODES',
#  'D25-13326-2-7331E_guide_split_BARCODES',
#  'D25-13328-1-7331E_guide_split_BARCODES',
#  'D25-13328-2-7331E_guide_split_BARCODES',
#  'D25-13329-1-7331E_guide_split_BARCODES',
#  'D25-13329-2-7331E_guide_split_BARCODES',
#  'D25-13330-1-7331E_guide_split_BARCODES',
#  'D25-13330-2-7331E_guide_split_BARCODES',
#  'D25-13332-1-7331E_guide_split_BARCODES',
#  'D25-13332-2-7331E_guide_split_BARCODES',
#  'D25-13333-1-7331E_guide_split_BARCODES',
#  'D25-13333-2-7331E_guide_split_BARCODES',
#  'D25-13337-1-7331E_guide_split_BARCODES',
#  'D25-13337-2-7331E_guide_split_BARCODES',
#  'D25-13788-1-7331E_guide_split_BARCODES',
#  'D25-13788-2-7331E_guide_split_BARCODES',
#  'D25-13789-1-7331E_guide_split_BARCODES',
#  'D25-13789-2-7331E_guide_split_BARCODES',
#  'D25-13790-1-7331E_guide_split_BARCODES',
#  'D25-13790-2-7331E_guide_split_BARCODES',
#  'D25-13791-1-7331E_guide_split_BARCODES',
#  'D25-13791-2-7331E_guide_split_BARCODES',
#  'D25-13792-1-7331E_guide_split_BARCODES',
#  'D25-13792-2-7331E_guide_split_BARCODES',
#  'D25-13793-1-7331E_guide_split_BARCODES',
#  'D25-13793-2-7331E_guide_split_BARCODES',
#  'D25-13794-1-7331E_guide_split_BARCODES',
#  'D25-13794-2-7331E_guide_split_BARCODES',
#  'D25-13795-1-7331E_guide_split_BARCODES',
#  'D25-13795-2-7331E_guide_split_BARCODES',
#  'D25-13796-1-7331E_guide_split_BARCODES',
#  'D25-13796-2-7331E_guide_split_BARCODES',
#  'D25-13797-1-7331E_guide_split_BARCODES',
#  'D25-13797-2-7331E_guide_split_BARCODES']

# %%
id_in_vivo = []
for y in range(5):
    for x in ['spleen','bm','men']:
        for z in range(2):
            id_in_vivo.append(f'{x}{y+1}-{z+1}')
id_in_vivo
# Out:
# ['spleen1-1',
#  'spleen1-2',
#  'bm1-1',
#  'bm1-2',
#  'men1-1',
#  'men1-2',
#  'spleen2-1',
#  'spleen2-2',
#  'bm2-1',
#  'bm2-2',
#  'men2-1',
#  'men2-2',
#  'spleen3-1',
#  'spleen3-2',
#  'bm3-1',
#  'bm3-2',
#  'men3-1',
#  'men3-2',
#  'spleen4-1',
#  'spleen4-2',
#  'bm4-1',
#  'bm4-2',
#  'men4-1',
#  'men4-2',
#  'spleen5-1',
#  'spleen5-2',
#  'bm5-1',
#  'bm5-2',
#  'men5-1',
#  'men5-2']

# %%
samp_ABE_BC = [
    'D25-13337-1-7331E','D25-13337-2-7331E', #library

    'D25-13245-1-7331E','D25-13245-2-7331E', #input

    'D25-13251-1-7331E','D25-13251-2-7331E', #in vitro d5

    'D25-13317-1-7331E','D25-13317-2-7331E', #in vitro d15
    'D25-13788-1-7331E','D25-13788-2-7331E',
    'D25-13789-1-7331E','D25-13789-2-7331E',
    'D25-13790-1-7331E','D25-13790-2-7331E',
    'D25-13321-1-7331E','D25-13321-2-7331E',

    'D25-13278-1-7331E','D25-13278-2-7331E', #spleen1
    'D25-13279-1-7331E','D25-13279-2-7331E', #bm1
    'D25-13280-1-7331E','D25-13280-2-7331E', #men1
    'D25-13281-1-7331E','D25-13281-2-7331E',
    'D25-13282-1-7331E','D25-13282-2-7331E',
    'D25-13283-1-7331E','D25-13283-2-7331E',
    'D25-13284-1-7331E','D25-13284-2-7331E',
    'D25-13285-1-7331E','D25-13285-2-7331E',
    'D25-13286-1-7331E','D25-13286-2-7331E',
    'D25-13287-1-7331E','D25-13287-2-7331E',
    'D25-13288-1-7331E','D25-13288-2-7331E',
    'D25-13289-1-7331E','D25-13289-2-7331E',
    'D25-13290-1-7331E','D25-13290-2-7331E',
    'D25-13291-1-7331E','D25-13291-2-7331E',
    'D25-13292-1-7331E','D25-13292-2-7331E',
]
samp_ABE_BC = [f'{x}_guide_split_BARCODES' for x in samp_ABE_BC]
id_abe_bc_d15 = []
for y in range(5):
    for z in range(2):
        id_abe_bc_d15.append(f'd15-rep{y+1}-{z+1}')
id_abe_bc_d15

samp_id_ABE_BC = [
    'lib-1','lib-2',
    'input-1','input-2',
    'd5-1','d5-2',
] + id_abe_bc_d15 + id_in_vivo

ABE_BC = dict(zip(samp_ABE_BC, samp_id_ABE_BC))
ABE_BC
# Out:
# {'D25-13337-1-7331E_guide_split_BARCODES': 'lib-1',
#  'D25-13337-2-7331E_guide_split_BARCODES': 'lib-2',
#  'D25-13245-1-7331E_guide_split_BARCODES': 'input-1',
#  'D25-13245-2-7331E_guide_split_BARCODES': 'input-2',
#  'D25-13251-1-7331E_guide_split_BARCODES': 'd5-1',
#  'D25-13251-2-7331E_guide_split_BARCODES': 'd5-2',
#  'D25-13317-1-7331E_guide_split_BARCODES': 'd15-rep1-1',
#  'D25-13317-2-7331E_guide_split_BARCODES': 'd15-rep1-2',
#  'D25-13788-1-7331E_guide_split_BARCODES': 'd15-rep2-1',
#  'D25-13788-2-7331E_guide_split_BARCODES': 'd15-rep2-2',
#  'D25-13789-1-7331E_guide_split_BARCODES': 'd15-rep3-1',
#  'D25-13789-2-7331E_guide_split_BARCODES': 'd15-rep3-2',
#  'D25-13790-1-7331E_guide_split_BARCODES': 'd15-rep4-1',
#  'D25-13790-2-7331E_guide_split_BARCODES': 'd15-rep4-2',
#  'D25-13321-1-7331E_guide_split_BARCODES': 'd15-rep5-1',
#  'D25-13321-2-7331E_guide_split_BARCODES': 'd15-rep5-2',
#  'D25-13278-1-7331E_guide_split_BARCODES': 'spleen1-1',
#  'D25-13278-2-7331E_guide_split_BARCODES': 'spleen1-2',
#  'D25-13279-1-7331E_guide_split_BARCODES': 'bm1-1',
#  'D25-13279-2-7331E_guide_split_BARCODES': 'bm1-2',
#  'D25-13280-1-7331E_guide_split_BARCODES': 'men1-1',
#  'D25-13280-2-7331E_guide_split_BARCODES': 'men1-2',
#  'D25-13281-1-7331E_guide_split_BARCODES': 'spleen2-1',
#  'D25-13281-2-7331E_guide_split_BARCODES': 'spleen2-2',
#  'D25-13282-1-7331E_guide_split_BARCODES': 'bm2-1',
#  'D25-13282-2-7331E_guide_split_BARCODES': 'bm2-2',
#  'D25-13283-1-7331E_guide_split_BARCODES': 'men2-1',
#  'D25-13283-2-7331E_guide_split_BARCODES': 'men2-2',
#  'D25-13284-1-7331E_guide_split_BARCODES': 'spleen3-1',
#  'D25-13284-2-7331E_guide_split_BARCODES': 'spleen3-2',
#  'D25-13285-1-7331E_guide_split_BARCODES': 'bm3-1',
#  'D25-13285-2-7331E_guide_split_BARCODES': 'bm3-2',
#  'D25-13286-1-7331E_guide_split_BARCODES': 'men3-1',
#  'D25-13286-2-7331E_guide_split_BARCODES': 'men3-2',
#  'D25-13287-1-7331E_guide_split_BARCODES': 'spleen4-1',
#  'D25-13287-2-7331E_guide_split_BARCODES': 'spleen4-2',
#  'D25-13288-1-7331E_guide_split_BARCODES': 'bm4-1',
#  'D25-13288-2-7331E_guide_split_BARCODES': 'bm4-2',
#  'D25-13289-1-7331E_guide_split_BARCODES': 'men4-1',
#  'D25-13289-2-7331E_guide_split_BARCODES': 'men4-2',
#  'D25-13290-1-7331E_guide_split_BARCODES': 'spleen5-1',
#  'D25-13290-2-7331E_guide_split_BARCODES': 'spleen5-2',
#  'D25-13291-1-7331E_guide_split_BARCODES': 'bm5-1',
#  'D25-13291-2-7331E_guide_split_BARCODES': 'bm5-2',
#  'D25-13292-1-7331E_guide_split_BARCODES': 'men5-1',
#  'D25-13292-2-7331E_guide_split_BARCODES': 'men5-2'}

# %%
samp_ABE_EPO = [
    'D25-13337-1-7331E','D25-13337-2-7331E', #library

    'D25-13245-1-7331E','D25-13245-2-7331E', #input

    'D25-13257-1-7331E','D25-13257-2-7331E', #in vitro d5

    'D25-13322-1-7331E','D25-13322-2-7331E', #in vitro d15
    'D25-13791-1-7331E','D25-13791-2-7331E',
    'D25-13324-1-7331E','D25-13324-2-7331E',
    'D25-13325-1-7331E','D25-13325-2-7331E',
    'D25-13326-1-7331E','D25-13326-2-7331E',

    'D25-13263-1-7331E','D25-13263-2-7331E',#spleen1
    'D25-13264-1-7331E','D25-13264-2-7331E',#bm1
    'D25-13265-1-7331E','D25-13265-2-7331E',#men1
    'D25-13266-1-7331E','D25-13266-2-7331E',
    'D25-13267-1-7331E','D25-13267-2-7331E',
    'D25-13268-1-7331E','D25-13268-2-7331E',
    'D25-13269-1-7331E','D25-13269-2-7331E',
    'D25-13270-1-7331E','D25-13270-2-7331E',
    'D25-13271-1-7331E','D25-13271-2-7331E',
    'D25-13272-1-7331E','D25-13272-2-7331E',
    'D25-13273-1-7331E','D25-13273-2-7331E',
    'D25-13274-1-7331E','D25-13274-2-7331E',
    'D25-13275-1-7331E','D25-13275-2-7331E',
    'D25-13276-1-7331E','D25-13276-2-7331E',
    'D25-13277-1-7331E','D25-13277-2-7331E',

]
samp_ABE_EPO = [f'{x}_guide_split_BARCODES' for x in samp_ABE_EPO]
id_abe_bc_d15 = []
for y in range(5):
    for z in range(2):
        id_abe_bc_d15.append(f'd15-rep{y+1}-{z+1}')
id_abe_bc_d15

samp_id_ABE_EPO = [
    'lib-1','lib-2',
    'input-1','input-2',
    'd5-1','d5-2',
] + id_abe_bc_d15 + id_in_vivo

print(len(samp_ABE_EPO),len(samp_id_ABE_EPO))

ABE_EPO = dict(zip(samp_ABE_EPO, samp_id_ABE_EPO))
ABE_EPO
# Out:
# 46 46
# {'D25-13337-1-7331E_guide_split_BARCODES': 'lib-1',
#  'D25-13337-2-7331E_guide_split_BARCODES': 'lib-2',
#  'D25-13245-1-7331E_guide_split_BARCODES': 'input-1',
#  'D25-13245-2-7331E_guide_split_BARCODES': 'input-2',
#  'D25-13257-1-7331E_guide_split_BARCODES': 'd5-1',
#  'D25-13257-2-7331E_guide_split_BARCODES': 'd5-2',
#  'D25-13322-1-7331E_guide_split_BARCODES': 'd15-rep1-1',
#  'D25-13322-2-7331E_guide_split_BARCODES': 'd15-rep1-2',
#  'D25-13791-1-7331E_guide_split_BARCODES': 'd15-rep2-1',
#  'D25-13791-2-7331E_guide_split_BARCODES': 'd15-rep2-2',
#  'D25-13324-1-7331E_guide_split_BARCODES': 'd15-rep3-1',
#  'D25-13324-2-7331E_guide_split_BARCODES': 'd15-rep3-2',
#  'D25-13325-1-7331E_guide_split_BARCODES': 'd15-rep4-1',
#  'D25-13325-2-7331E_guide_split_BARCODES': 'd15-rep4-2',
#  'D25-13326-1-7331E_guide_split_BARCODES': 'd15-rep5-1',
#  'D25-13326-2-7331E_guide_split_BARCODES': 'd15-rep5-2',
#  'D25-13263-1-7331E_guide_split_BARCODES': 'spleen1-1',
#  'D25-13263-2-7331E_guide_split_BARCODES': 'spleen1-2',
#  'D25-13264-1-7331E_guide_split_BARCODES': 'bm1-1',
#  'D25-13264-2-7331E_guide_split_BARCODES': 'bm1-2',
#  'D25-13265-1-7331E_guide_split_BARCODES': 'men1-1',
#  'D25-13265-2-7331E_guide_split_BARCODES': 'men1-2',
#  'D25-13266-1-7331E_guide_split_BARCODES': 'spleen2-1',
#  'D25-13266-2-7331E_guide_split_BARCODES': 'spleen2-2',
#  'D25-13267-1-7331E_guide_split_BARCODES': 'bm2-1',
#  'D25-13267-2-7331E_guide_split_BARCODES': 'bm2-2',
#  'D25-13268-1-7331E_guide_split_BARCODES': 'men2-1',
#  'D25-13268-2-7331E_guide_split_BARCODES': 'men2-2',
#  'D25-13269-1-7331E_guide_split_BARCODES': 'spleen3-1',
#  'D25-13269-2-7331E_guide_split_BARCODES': 'spleen3-2',
#  'D25-13270-1-7331E_guide_split_BARCODES': 'bm3-1',
#  'D25-13270-2-7331E_guide_split_BARCODES': 'bm3-2',
#  'D25-13271-1-7331E_guide_split_BARCODES': 'men3-1',
#  'D25-13271-2-7331E_guide_split_BARCODES': 'men3-2',
#  'D25-13272-1-7331E_guide_split_BARCODES': 'spleen4-1',
#  'D25-13272-2-7331E_guide_split_BARCODES': 'spleen4-2',
#  'D25-13273-1-7331E_guide_split_BARCODES': 'bm4-1',
#  'D25-13273-2-7331E_guide_split_BARCODES': 'bm4-2',
#  'D25-13274-1-7331E_guide_split_BARCODES': 'men4-1',
#  'D25-13274-2-7331E_guide_split_BARCODES': 'men4-2',
#  'D25-13275-1-7331E_guide_split_BARCODES': 'spleen5-1',
#  'D25-13275-2-7331E_guide_split_BARCODES': 'spleen5-2',
#  'D25-13276-1-7331E_guide_split_BARCODES': 'bm5-1',
#  'D25-13276-2-7331E_guide_split_BARCODES': 'bm5-2',
#  'D25-13277-1-7331E_guide_split_BARCODES': 'men5-1',
#  'D25-13277-2-7331E_guide_split_BARCODES': 'men5-2'}

# %%
samp_CBE_BC = [
    'D25-13797-1-7331E','D25-13797-2-7331E', #library
    
    'D25-13246-1-7331E','D25-13246-2-7331E', #input rep1-5
    'D25-13247-1-7331E','D25-13247-2-7331E',
    'D25-13248-1-7331E','D25-13248-2-7331E',
    'D25-13249-1-7331E','D25-13249-2-7331E',
    'D25-13250-1-7331E','D25-13250-2-7331E',

    'D25-13252-1-7331E','D25-13252-2-7331E', #d5 rep1-5
    'D25-13253-1-7331E','D25-13253-2-7331E',
    'D25-13254-1-7331E','D25-13254-2-7331E',
    'D25-13255-1-7331E','D25-13255-2-7331E',
    'D25-13256-1-7331E','D25-13256-2-7331E',

    'D25-13792-1-7331E','D25-13792-2-7331E', #d15 rep1-5
    'D25-13328-1-7331E','D25-13328-2-7331E',
    'D25-13329-1-7331E','D25-13329-2-7331E',
    'D25-13330-1-7331E','D25-13330-2-7331E',
    'D25-13793-1-7331E','D25-13793-2-7331E',

    'D25-13308-1-7331E','D25-13308-2-7331E', #spleen1
    'D25-13309-1-7331E','D25-13309-2-7331E', #bm1
    'D25-13310-1-7331E','D25-13310-2-7331E', #men1
    'D25-13311-1-7331E','D25-13311-2-7331E', #spleen2
    'D25-13312-1-7331E','D25-13312-2-7331E', #bm2
    'D25-13313-1-7331E','D25-13313-2-7331E', #men2
    'D25-13314-1-7331E','D25-13314-2-7331E', #spleen4
    'D25-13315-1-7331E','D25-13315-2-7331E', #bm4
    'D25-13316-1-7331E','D25-13316-2-7331E', #men4
]
samp_CBE_BC = [f'{x}_guide_split_BARCODES' for x in samp_CBE_BC]
id_cbe = []
for x in ['input','d5','d15']:
    for y in range(5):
        for z in range(2):
            id_cbe.append(f'{x}-rep{y+1}-{z+1}')
id_cbe

in_vivo_id_1_2_4 = []
for y in [0,1,3]:
    for x in ['spleen','bm','men']:
        for z in range(2):
            in_vivo_id_1_2_4.append(f'{x}{y+1}-{z+1}')
id_in_vivo

samp_id_CBE_BC = ['lib-1','lib-2'] + id_cbe + in_vivo_id_1_2_4
print(len(samp_CBE_BC),len(samp_id_CBE_BC))

CBE_BC = dict(zip(samp_CBE_BC, samp_id_CBE_BC))
CBE_BC
# Out:
# 50 50
# {'D25-13797-1-7331E_guide_split_BARCODES': 'lib-1',
#  'D25-13797-2-7331E_guide_split_BARCODES': 'lib-2',
#  'D25-13246-1-7331E_guide_split_BARCODES': 'input-rep1-1',
#  'D25-13246-2-7331E_guide_split_BARCODES': 'input-rep1-2',
#  'D25-13247-1-7331E_guide_split_BARCODES': 'input-rep2-1',
#  'D25-13247-2-7331E_guide_split_BARCODES': 'input-rep2-2',
#  'D25-13248-1-7331E_guide_split_BARCODES': 'input-rep3-1',
#  'D25-13248-2-7331E_guide_split_BARCODES': 'input-rep3-2',
#  'D25-13249-1-7331E_guide_split_BARCODES': 'input-rep4-1',
#  'D25-13249-2-7331E_guide_split_BARCODES': 'input-rep4-2',
#  'D25-13250-1-7331E_guide_split_BARCODES': 'input-rep5-1',
#  'D25-13250-2-7331E_guide_split_BARCODES': 'input-rep5-2',
#  'D25-13252-1-7331E_guide_split_BARCODES': 'd5-rep1-1',
#  'D25-13252-2-7331E_guide_split_BARCODES': 'd5-rep1-2',
#  'D25-13253-1-7331E_guide_split_BARCODES': 'd5-rep2-1',
#  'D25-13253-2-7331E_guide_split_BARCODES': 'd5-rep2-2',
#  'D25-13254-1-7331E_guide_split_BARCODES': 'd5-rep3-1',
#  'D25-13254-2-7331E_guide_split_BARCODES': 'd5-rep3-2',
#  'D25-13255-1-7331E_guide_split_BARCODES': 'd5-rep4-1',
#  'D25-13255-2-7331E_guide_split_BARCODES': 'd5-rep4-2',
#  'D25-13256-1-7331E_guide_split_BARCODES': 'd5-rep5-1',
#  'D25-13256-2-7331E_guide_split_BARCODES': 'd5-rep5-2',
#  'D25-13792-1-7331E_guide_split_BARCODES': 'd15-rep1-1',
#  'D25-13792-2-7331E_guide_split_BARCODES': 'd15-rep1-2',
#  'D25-13328-1-7331E_guide_split_BARCODES': 'd15-rep2-1',
#  'D25-13328-2-7331E_guide_split_BARCODES': 'd15-rep2-2',
#  'D25-13329-1-7331E_guide_split_BARCODES': 'd15-rep3-1',
#  'D25-13329-2-7331E_guide_split_BARCODES': 'd15-rep3-2',
#  'D25-13330-1-7331E_guide_split_BARCODES': 'd15-rep4-1',
#  'D25-13330-2-7331E_guide_split_BARCODES': 'd15-rep4-2',
#  'D25-13793-1-7331E_guide_split_BARCODES': 'd15-rep5-1',
#  'D25-13793-2-7331E_guide_split_BARCODES': 'd15-rep5-2',
#  'D25-13308-1-7331E_guide_split_BARCODES': 'spleen1-1',
#  'D25-13308-2-7331E_guide_split_BARCODES': 'spleen1-2',
#  'D25-13309-1-7331E_guide_split_BARCODES': 'bm1-1',
#  'D25-13309-2-7331E_guide_split_BARCODES': 'bm1-2',
#  'D25-13310-1-7331E_guide_split_BARCODES': 'men1-1',
#  'D25-13310-2-7331E_guide_split_BARCODES': 'men1-2',
#  'D25-13311-1-7331E_guide_split_BARCODES': 'spleen2-1',
#  'D25-13311-2-7331E_guide_split_BARCODES': 'spleen2-2',
#  'D25-13312-1-7331E_guide_split_BARCODES': 'bm2-1',
#  'D25-13312-2-7331E_guide_split_BARCODES': 'bm2-2',
#  'D25-13313-1-7331E_guide_split_BARCODES': 'men2-1',
#  'D25-13313-2-7331E_guide_split_BARCODES': 'men2-2',
#  'D25-13314-1-7331E_guide_split_BARCODES': 'spleen4-1',
#  'D25-13314-2-7331E_guide_split_BARCODES': 'spleen4-2',
#  'D25-13315-1-7331E_guide_split_BARCODES': 'bm4-1',
#  'D25-13315-2-7331E_guide_split_BARCODES': 'bm4-2',
#  'D25-13316-1-7331E_guide_split_BARCODES': 'men4-1',
#  'D25-13316-2-7331E_guide_split_BARCODES': 'men4-2'}

# %%
samp_CBE_EPO = [
    'D25-13797-1-7331E','D25-13797-2-7331E', #library
    
    'D25-13246-1-7331E','D25-13246-2-7331E', #input rep1-5
    'D25-13247-1-7331E','D25-13247-2-7331E',
    'D25-13248-1-7331E','D25-13248-2-7331E',
    'D25-13249-1-7331E','D25-13249-2-7331E',
    'D25-13250-1-7331E','D25-13250-2-7331E',

    'D25-13258-1-7331E','D25-13258-2-7331E', #d5 rep1-5
    'D25-13259-1-7331E','D25-13259-2-7331E',
    'D25-13260-1-7331E','D25-13260-2-7331E',
    'D25-13261-1-7331E','D25-13261-2-7331E',
    'D25-13262-1-7331E','D25-13262-2-7331E',

    'D25-13332-1-7331E','D25-13332-2-7331E', #d15 rep1-5
    'D25-13333-1-7331E','D25-13333-2-7331E', 
    'D25-13794-1-7331E','D25-13794-2-7331E',
    'D25-13795-1-7331E','D25-13795-2-7331E',
    'D25-13796-1-7331E','D25-13796-2-7331E',

    'D25-13293-1-7331E','D25-13293-2-7331E', #spleen1
    'D25-13294-1-7331E','D25-13294-2-7331E', #bm1
    'D25-13295-1-7331E','D25-13295-2-7331E', #men1
    'D25-13296-1-7331E','D25-13296-2-7331E',
    'D25-13297-1-7331E','D25-13297-2-7331E',
    'D25-13298-1-7331E','D25-13298-2-7331E',
    'D25-13299-1-7331E','D25-13299-2-7331E',
    'D25-13300-1-7331E','D25-13300-2-7331E',
    'D25-13301-1-7331E','D25-13301-2-7331E',
    'D25-13302-1-7331E','D25-13302-2-7331E',
    'D25-13303-1-7331E','D25-13303-2-7331E',
    'D25-13304-1-7331E','D25-13304-2-7331E',
    'D25-13305-1-7331E','D25-13305-2-7331E',
    'D25-13306-1-7331E','D25-13306-2-7331E',
    'D25-13307-1-7331E','D25-13307-2-7331E',
]

samp_CBE_EPO = [f'{x}_guide_split_BARCODES' for x in samp_CBE_EPO]
id_cbe = []
for x in ['input','d5','d15']:
    for y in range(5):
        for z in range(2):
            id_cbe.append(f'{x}-rep{y+1}-{z+1}')
id_cbe

samp_id_CBE_EPO= ['lib-1','lib-2'] + id_cbe + id_in_vivo

print(len(samp_CBE_EPO),len(samp_id_CBE_EPO))

samp_id_CBE_EPO = [ f'{x}_CBE_EPO' for x in samp_id_CBE_EPO]

CBE_EPO = dict(zip(samp_CBE_EPO, samp_id_CBE_EPO))
CBE_EPO
# Out:
# 62 62
# {'D25-13797-1-7331E_guide_split_BARCODES': 'lib-1_CBE_EPO',
#  'D25-13797-2-7331E_guide_split_BARCODES': 'lib-2_CBE_EPO',
#  'D25-13246-1-7331E_guide_split_BARCODES': 'input-rep1-1_CBE_EPO',
#  'D25-13246-2-7331E_guide_split_BARCODES': 'input-rep1-2_CBE_EPO',
#  'D25-13247-1-7331E_guide_split_BARCODES': 'input-rep2-1_CBE_EPO',
#  'D25-13247-2-7331E_guide_split_BARCODES': 'input-rep2-2_CBE_EPO',
#  'D25-13248-1-7331E_guide_split_BARCODES': 'input-rep3-1_CBE_EPO',
#  'D25-13248-2-7331E_guide_split_BARCODES': 'input-rep3-2_CBE_EPO',
#  'D25-13249-1-7331E_guide_split_BARCODES': 'input-rep4-1_CBE_EPO',
#  'D25-13249-2-7331E_guide_split_BARCODES': 'input-rep4-2_CBE_EPO',
#  'D25-13250-1-7331E_guide_split_BARCODES': 'input-rep5-1_CBE_EPO',
#  'D25-13250-2-7331E_guide_split_BARCODES': 'input-rep5-2_CBE_EPO',
#  'D25-13258-1-7331E_guide_split_BARCODES': 'd5-rep1-1_CBE_EPO',
#  'D25-13258-2-7331E_guide_split_BARCODES': 'd5-rep1-2_CBE_EPO',
#  'D25-13259-1-7331E_guide_split_BARCODES': 'd5-rep2-1_CBE_EPO',
#  'D25-13259-2-7331E_guide_split_BARCODES': 'd5-rep2-2_CBE_EPO',
#  'D25-13260-1-7331E_guide_split_BARCODES': 'd5-rep3-1_CBE_EPO',
#  'D25-13260-2-7331E_guide_split_BARCODES': 'd5-rep3-2_CBE_EPO',
#  'D25-13261-1-7331E_guide_split_BARCODES': 'd5-rep4-1_CBE_EPO',
#  'D25-13261-2-7331E_guide_split_BARCODES': 'd5-rep4-2_CBE_EPO',
#  'D25-13262-1-7331E_guide_split_BARCODES': 'd5-rep5-1_CBE_EPO',
#  'D25-13262-2-7331E_guide_split_BARCODES': 'd5-rep5-2_CBE_EPO',
#  'D25-13332-1-7331E_guide_split_BARCODES': 'd15-rep1-1_CBE_EPO',
#  'D25-13332-2-7331E_guide_split_BARCODES': 'd15-rep1-2_CBE_EPO',
#  'D25-13333-1-7331E_guide_split_BARCODES': 'd15-rep2-1_CBE_EPO',
#  'D25-13333-2-7331E_guide_split_BARCODES': 'd15-rep2-2_CBE_EPO',
#  'D25-13794-1-7331E_guide_split_BARCODES': 'd15-rep3-1_CBE_EPO',
#  'D25-13794-2-7331E_guide_split_BARCODES': 'd15-rep3-2_CBE_EPO',
#  'D25-13795-1-7331E_guide_split_BARCODES': 'd15-rep4-1_CBE_EPO',
#  'D25-13795-2-7331E_guide_split_BARCODES': 'd15-rep4-2_CBE_EPO',
#  'D25-13796-1-7331E_guide_split_BARCODES': 'd15-rep5-1_CBE_EPO',
#  'D25-13796-2-7331E_guide_split_BARCODES': 'd15-rep5-2_CBE_EPO',
#  'D25-13293-1-7331E_guide_split_BARCODES': 'spleen1-1_CBE_EPO',
#  'D25-13293-2-7331E_guide_split_BARCODES': 'spleen1-2_CBE_EPO',
#  'D25-13294-1-7331E_guide_split_BARCODES': 'bm1-1_CBE_EPO',
#  'D25-13294-2-7331E_guide_split_BARCODES': 'bm1-2_CBE_EPO',
#  'D25-13295-1-7331E_guide_split_BARCODES': 'men1-1_CBE_EPO',
#  'D25-13295-2-7331E_guide_split_BARCODES': 'men1-2_CBE_EPO',
#  'D25-13296-1-7331E_guide_split_BARCODES': 'spleen2-1_CBE_EPO',
#  'D25-13296-2-7331E_guide_split_BARCODES': 'spleen2-2_CBE_EPO',
#  'D25-13297-1-7331E_guide_split_BARCODES': 'bm2-1_CBE_EPO',
#  'D25-13297-2-7331E_guide_split_BARCODES': 'bm2-2_CBE_EPO',
#  'D25-13298-1-7331E_guide_split_BARCODES': 'men2-1_CBE_EPO',
#  'D25-13298-2-7331E_guide_split_BARCODES': 'men2-2_CBE_EPO',
#  'D25-13299-1-7331E_guide_split_BARCODES': 'spleen3-1_CBE_EPO',
#  'D25-13299-2-7331E_guide_split_BARCODES': 'spleen3-2_CBE_EPO',
#  'D25-13300-1-7331E_guide_split_BARCODES': 'bm3-1_CBE_EPO',
#  'D25-13300-2-7331E_guide_split_BARCODES': 'bm3-2_CBE_EPO',
#  'D25-13301-1-7331E_guide_split_BARCODES': 'men3-1_CBE_EPO',
#  'D25-13301-2-7331E_guide_split_BARCODES': 'men3-2_CBE_EPO',
#  'D25-13302-1-7331E_guide_split_BARCODES': 'spleen4-1_CBE_EPO',
#  'D25-13302-2-7331E_guide_split_BARCODES': 'spleen4-2_CBE_EPO',
#  'D25-13303-1-7331E_guide_split_BARCODES': 'bm4-1_CBE_EPO',
#  'D25-13303-2-7331E_guide_split_BARCODES': 'bm4-2_CBE_EPO',
#  'D25-13304-1-7331E_guide_split_BARCODES': 'men4-1_CBE_EPO',
#  'D25-13304-2-7331E_guide_split_BARCODES': 'men4-2_CBE_EPO',
#  'D25-13305-1-7331E_guide_split_BARCODES': 'spleen5-1_CBE_EPO',
#  'D25-13305-2-7331E_guide_split_BARCODES': 'spleen5-2_CBE_EPO',
#  'D25-13306-1-7331E_guide_split_BARCODES': 'bm5-1_CBE_EPO',
#  'D25-13306-2-7331E_guide_split_BARCODES': 'bm5-2_CBE_EPO',
#  'D25-13307-1-7331E_guide_split_BARCODES': 'men5-1_CBE_EPO',
#  'D25-13307-2-7331E_guide_split_BARCODES': 'men5-2_CBE_EPO'}

# %%
#and then add in the gene information as well
df = pd.read_csv('/Users/kexindong/Documents/GitHub/PhD-FSR-MH-Lab/07_B-ALL_resubmission_20250819/validation_screen_analysis/STEP3_generate_config_file/FINAL_focused_library.csv')
df['classification'].value_counts()
# Out:
# classification
# targeting guide               952
# non-targeting control         488
# essential truncation guide    115
# safe-targeting control         78
# Name: count, dtype: int64

# %%
#and then add in the gene information as well
df = pd.read_csv('/Users/kexindong/Documents/GitHub/PhD-FSR-MH-Lab/07_B-ALL_resubmission_20250819/validation_screen_analysis/STEP3_generate_config_file/FINAL_focused_library.csv')
guide_gene = dict(zip(df['gRNA_id'], df['gene_name_m']))
class_gene = dict(zip(df['gRNA_id'], df['classification']))

# %%
fp = '/Users/kexindong/Documents/GitHub/PhD-FSR-MH-Lab/07_B-ALL_resubmission_20250819/validation_screen_analysis/counts'
chosen_count_column = 'bc_count' #can also choose "matched_guide_count" or "total_guide_count"
df_holder = []

def count_matrix(dictionary, samp, samp_id):
    df_holder = []
    for i, k in enumerate(samp):
        aa = pd.read_csv(f'{fp}/{k}_count_df.csv')
        aa = aa[['Guide_ID', chosen_count_column]]
        s = dictionary[k]
        aa = aa.rename(columns = {chosen_count_column:f'{s}'})

        if i>0:
            aa = aa.rename(columns = {'Guide_ID':'Guide_ID_x'})
        df_holder.append(aa)

    join_out = pd.concat(df_holder, axis=1)
    sample_id_expanded_to_add = []
    for x in samp_id:
        if x in join_out.columns:
            sample_id_expanded_to_add.append(x)
    join_out = join_out[['Guide_ID'] + sample_id_expanded_to_add]
    join_out = join_out.loc[:, ~join_out.columns.duplicated()]

    genes = []
    for i, val in join_out.iterrows():
        k = val['Guide_ID']
        #print(k)
        gene = guide_gene[k]
        #make all the neutral guides have the same name
        class_ = class_gene[k]
        if class_ in ['non-targeting control','safe-targeting control']:
            gene = 'controlsgRNA'
        genes.append(gene)
    join_out['gene'] = genes
    join_out = join_out.rename(columns = {'Guide_ID':'sgRNA'})
    cols = ['sgRNA', 'gene'] + [c for c in join_out.columns if c not in ['sgRNA', 'gene']]
    join_out = join_out[cols]

    samps_to_merge = [
            [samp_id[i], samp_id[i+1]]
            for i in range(0, len(samp_id), 2)
        ]
    new_sample_ids = np.unique([x.rsplit("-", 1)[0] for x in samp_id])
    # print(new_sample_ids)
    for i,x in enumerate(samps_to_merge):
        join_out[new_sample_ids[i]] = join_out[x].sum(axis=1)
        join_out = join_out.drop(columns = x)
    return join_out

# %%
ABE_BC_COUNTS = count_matrix(ABE_BC, samp_ABE_BC, samp_id_ABE_BC)
ABE_EPO_COUNTS = count_matrix(ABE_EPO, samp_ABE_EPO, samp_id_ABE_EPO)
CBE_BC_COUNTS = count_matrix(CBE_BC, samp_CBE_BC, samp_id_CBE_BC)
CBE_EPO_COUNTS = count_matrix(CBE_EPO, samp_CBE_EPO, samp_id_CBE_EPO)

# %%
df = pd.read_csv('/Users/kexindong/Documents/GitHub/PhD-FSR-MH-Lab/07_B-ALL_resubmission_20250819/validation_screen_analysis/STEP3_generate_config_file/FINAL_focused_library.csv')
CBE = df[df['Editor'] == 'CBE']
CBE_ids = CBE['gRNA_id'].tolist()
CBE_BC_COUNTS = CBE_BC_COUNTS[CBE_BC_COUNTS['sgRNA'].isin(CBE_ids)].reset_index(drop=True)
CBE_EPO_COUNTS = CBE_EPO_COUNTS[CBE_EPO_COUNTS['sgRNA'].isin(CBE_ids)].reset_index(drop=True)

ABE = df[df['Editor'] == 'ABE']
ABE_ids = ABE['gRNA_id'].tolist()
ABE_BC_COUNTS = ABE_BC_COUNTS[ABE_BC_COUNTS['sgRNA'].isin(ABE_ids)].reset_index(drop=True)
ABE_EPO_COUNTS = ABE_EPO_COUNTS[ABE_EPO_COUNTS['sgRNA'].isin(ABE_ids)].reset_index(drop=True)

# %%
#and finally save it for running on mageck
ABE_BC_COUNTS.to_csv('ABE_BC_COUNTS.txt', sep='\t', index=False)
ABE_EPO_COUNTS.to_csv('ABE_EPO_COUNTS.txt', sep='\t', index=False)
CBE_BC_COUNTS.to_csv('CBE_BC_COUNTS.txt', sep='\t', index=False)
CBE_EPO_COUNTS.to_csv('CBE_EPO_COUNTS.txt', sep='\t', index=False)

# %%
# next time to read them: 
def load_dicts(base_path, name_list):
    """Load csvs into separate dictionaries based on folder names."""
    result = {}
    for name in name_list:
        folder = os.path.join(base_path, name)
        d = {}  # dictionary for this group
        for file in os.listdir(folder):
            if file.endswith("_compact_unfiltered.csv"):
                sample_name = file.replace("_compact_unfiltered.csv", "")
                filepath = os.path.join(folder, file)
                d[sample_name] = pd.read_csv(filepath)
        result[name] = d
    return result

# Usage
fp = '/Users/kexindong/Documents/GitHub/PhD-FSR-MH-Lab/07_B-ALL_resubmission_20250819/validation_screen_analysis/crispresso_data/compact_lane_merged_unfiltered'
name_list = ['ABE_BC', 'ABE_EPO', 'CBE_BC', 'CBE_EPO']

loaded = load_dicts(fp, name_list)

ABE_BC = loaded['ABE_BC']
ABE_EPO = loaded['ABE_EPO']
CBE_BC  = loaded['CBE_BC']
CBE_EPO = loaded['CBE_EPO']
