# %% [markdown]
# # Extended Data Figure 10
#
# Sam Gould, Kexin Dong
#
# CBE screen quality control, pipeline benchmarking, and hit identification.

# %% [markdown]
# # ED10a
#
# The 90/10 skew ratio (counts of 90th percentile guide/counts of 10th percentile guide) for each indicated sample for CBE screen.

# %% [markdown]
# # ED10b
#
# Principal components analysis of the correlation matrix of barcode counts for replicates of indicated CBE samples.

# %% [markdown]
# # ED10c
#
# Average target base editing % (with bystander edits allowed, dark blue) and pure correct editing % (no bystander edits allowed, light blue) at the sensor locus.

# %% [markdown]
# # ED10d
#
# Histogram of target base editing rate (top, dark blue) and pure correct editing rate (bottom, light blue) at the sensor locus for all samples of CBE screen.

# %% [markdown]
# # ED10e
#
# Scatter plots of empirical −log10(FDR) versus median LFC (top) and MAGeCK −log10(FDR) versus MAGeCK LFC (bottom) for CBE gRNAs across all tissue contexts, with no sensor editing cutoff applied. Dashed red lines indicate FDR = 0.1. Points colored by hits classification: empirical framework only (blue), MAGeCK only (orange), called by both pipelines (red), or neither (gray).

# %% [markdown]
# # ED10f
#
# Venn diagrams comparing significant hits (FDR < 0.1) identified by MAGeCK versus the empirical framework for CBE gRNAs across all tissue contexts. MAGeCK substantially overestimates the number of significant hits relative to the empirical framework, with the greatest excess of false-positive calls observed in the meninges compartment.

# %% [markdown]
# # ED10g
#
# Waterfall plots of CBE gRNA enrichment scores across all tissue contexts (target base editing ≥ 20%), with the top 10 and bottom 10 gRNAs labeled per context. Points colored by COSMIC Cancer Gene Census annotation; point size scaled by FDR significance.

# %% [markdown]
# # ED10h
#
# Heatmap of pairwise Spearman correlation coefficients between per-replicate LFC z-scores for all CBE samples. Spleen and bone marrow replicates show moderate inter-replicate concordance, while meninges and in vitro samples exhibit lower correlations consistent with reduced selective pressure and variable engraftment.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import seaborn as sns
import scipy.stats
from sklearn.decomposition import PCA
from adjustText import adjust_text
from matplotlib_venn import venn2, venn3
from upsetplot import UpSet, from_indicators
import warnings
import os
warnings.filterwarnings('ignore')

# ── Global style (matching published figures) ─────────────────────────────────────────
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype']  = 42
mpl.rcParams['text.usetex']  = False
plt.rcParams['font.family']     = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Helvetica']

blues   = sns.color_palette('Blues').as_hex()
greens  = sns.color_palette('Greens').as_hex()
reds    = sns.color_palette('Reds').as_hex()
yellows = sns.color_palette('Oranges').as_hex()
purples = sns.color_palette('Purples').as_hex()

greys = sns.color_palette('Greys').as_hex()
teals = sns.color_palette('BuPu').as_hex()
pinks = sns.color_palette('RdPu').as_hex()
browns = sns.color_palette('YlOrBr').as_hex()
BASE = '/Users/kexindong/Documents/GitHub/B-ALL-in-vivo-base-editing/'

# %% [markdown]
# ## 10a

# %% [markdown]
# ## 10b

# %% [markdown]
# ## 10c

# %% [markdown]
# ## 10d

# %% [markdown]
# ## 10e

# %% [markdown]
# ## 10f

# %% [markdown]
# ## 10g

# %% [markdown]
# ## 10h

# %% [markdown]
# ## 10i

# %% [markdown]
# ## 10j

# %% [markdown]
# ## 10k
